# %%
using EasyLinalg

using StatsPlots

# %%
using EasyLinalg

a = [ Arrow3D(1.0, 5.0, 2.0 )]#, Point3D(3.0, 2.0, 3.0), Point3D(3.0, 3.0,0.0), Point3D(2.0, 5.0, 2.0)  ]
b = 0.1

# c = convex_combination( a , b)

Draw(a)

# %%
savefig(Draw(a), "seta3d.png")

# %%
Draw(c,true)

# %%
using EasyLinalg

a = [ SignalBuildU(sin, -10.0:0.1:10.0), SignalBuildU(x -> sin(4.0 * x), -10.0:0.1:10.0) ]
b = 0.5

c = convex_combination( a , b)

Draw(c)

# %%
savefig(Draw(c), "Array-sinal.png")

# %%
using EasyLinalg

a = [ Image("bola.jpg"), Image("quadrado.jpg") ]
b = 0.5

c = convex_combination( a , b)

Draw(c)

# %%
function draw(S::Vector{<:Image})
    K = toNativeVector(S)
    display(K)
end
